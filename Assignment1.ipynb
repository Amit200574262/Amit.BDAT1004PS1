# %% [markdown]
# # Question 1
#
# What data type is each of the following (evaluate where necessary)?
#
# 5
# 5.0
# 5>1
# '5'
# 5*2
# '5' * 2
# '5' + '2'
# 5/2
# 5%2
# {5, 2, 1}
# 5 == 3
# Pi (the number)

# %%
5 - Integer 
5.0 - Float 
5 > 1 - Boolean  [This expression evaluates to True]
'5' - String 
5 * 2 - Integer 
'5' * 2 - String 
'5' + '2' - String 
5 / 2 - Float 
5 % 2 - Integer 
{5, 2, 1} - Set 
5 == 3 - Boolean  [This expression evaluates to False]
Pi (the number) - Float

# %% [markdown]
# # Question 2
#
# Write (and evaluate) python expressions that answer these questions:
#
# a. How many letters are there in 'Supercalifragilisticexpialidocious'?
# b. Does 'Supercalifragilisticexpialidocious' contain 'ice' as a substring?
# c. Which of the following words is the longest:Supercalifragilisticexpialidocious, Honorificabilitudinitatibus, orBababadalgharaghtakamminarronnkonn?
# d. Which composer comes first in the dictionary: 'Berlioz', 'Borodin', 'Brian','Bartok', 'Bellini', 'Buxtehude', 'Bernstein'. Which one comes last?

# %%
Answer (a) 

wrd = 'Supercalifragilisticexpialidocious'
no_letters = len(wrd)
print("Number of letters in ",wrd, ":-", no_letters)

Output :-  Number of letters in  Supercalifragilisticexpialidocious :- 34

    
        
        
Answer (b) 
    
wrd = 'Supercalifragilisticexpialidocious'
sbstrng = 'ice'
string_ice = sbstrng in wrd
print(wrd , "Contains 'ice'?  :- ", string_ice)


Output :-  Supercalifragilisticexpialidocious Contains 'ice'?  :-  True 

        

Answer (c) -
    
wrd1 = 'Supercalifragilisticexpialidocious'
wrd2 = 'Honorificabilitudinitatibus'
wrd3 = 'Bababadalgharaghtakamminarronnkonn'


lh1 = len(wrd1)
lh2 = len(wrd2)
lh3 = len(wrd3)

longst_lh = max(lh1, lh2, lh3)


if longst_lh == lh1:
    print("The longest word out of these is:", wrd1)
elif longst_lh == lh2:
    print("The longest word out of these is:", wrd2)
else:
    print("The longest word out of these is:", wrd3)


Output :- The longest word out of these is: Supercalifragilisticexpialidocious


        
Answer (d) :-  
    
dictionary = ['Berlioz', 'Borodin', 'Brian', 'Bartok', 'Bellini', 'Buxtehude', 'Bernstein']


first_wrd = min(dictionary)


last_wrd = max(dictionary)

print("First composer in dictionary :", first_wrd)
print("Last composer in dictionary:", last_wrd)


Output :- 
First composer in dictionary : Bartok

Last composer in dictionary: Buxtehude

# %% [markdown]
# # Question 3
#
# Implement function triangleArea(a,b,c) that takes as input the lengths of the 3sides of a triangle and returns the area of the triangle. By Heron's formula, the areaof a triangle with side lengths a, b, and c iss(s - a)(s - b)(s - c) , wheres = (a + b + c) /2.
#
# >>> triangleArea(2,2,2)
# 1.7320508075688772

# %%
import math

def triangleArea(a, b, c):
    s = (a + b + c) / 2
    area = math.sqrt(s * (s - a) * (s - b) * (s - c))
    return area

result = triangleArea(2, 2, 2)

print("The area of the triangle is:", result)

# %% [markdown]
# # Question 4
#
# Write a program in python to separate odd and even integers in separate arrays. Goto the editor
# Test Data :
# Input the number of elements to be stored in the array :5
# Input 5 elements in the array :
# element - 0 : 25
# element - 1 : 47
# element - 2 : 42
# element - 3 : 56
# element - 4 : 32
#
# Expected Output:
# The Even elements are:
# 42 56 32
# The Odd elements are :
# 25 4

# %%
a = [25, 47, 42, 56, 32]


even_numbers = []
odd_numbers = []


for num in a:
    if num % 2 == 0:
        even_numbers.append(num) 
    else:
        odd_numbers.append(num)  


print("The Even elements are:", even_numbers)
print("The Odd elements are:", odd_numbers)

# %% [markdown]
# # Question 5
#
# a. Write a function inside(x,y,x1,y1,x2,y2) that returns True or Falsedepending on whether the point (x,y) lies in the rectangle with lower leftcorner (x1,y1) and upper right corner (x2,y2).
#
# inside(1,1,0,0,2,3)
# True
#
# inside(-1,-1,0,0,2,3)
# False
#
# b. Use function inside() from part a. to write an expression that tests whetherthe point (1,1) lies in both of the following rectangles: one with lower leftcorner (0.3, 0.5) and upper right corner (1.1, 0.7) and the other with lowerleft corner (0.5, 0.2) and upper right corner (1.1, 2).

# %%
a) 

def a(x, y, x1, y1, x2, y2):

    if x1 <= x <= x2 and y1 <= y <= y2:
        return True
    else:
        return False


result1 = a(1, 1, 0, 0, 2, 3)    
result2 = a(-1, -1, 0, 0, 2, 3)  

print(result1)
print(result2)



b)

def inside(x, y, x1, y1, x2, y2):
  
    if x1 <= x <= x2 and y1 <= y <= y2:
        return True
    else:
        return False


r1_x1, r1_y1, r1_x2, r1_y2 = 0.3, 0.5, 1.1, 0.7
r2_x1, r2_y1, r2_x2, r2_y2 = 0.5, 0.2, 1.1, 2

point_in_r1 = inside(1, 1, r1_x1, r1_y1, r1_x2, r1_y2)
point_in_r2 = inside(1, 1, r2_x1, r2_y1, r2_x2, r2_y2)


if point_in_r1 and point_in_r2:
    print("The point (1, 1) is inside both rectangles.")
else:
    print("The point (1, 1) is not inside both rectangles.")

# %% [markdown]
# # Question 6
#
# You can turn a word into pig-Latin using the following two rules (simplified):
# • If the word starts with a consonant, move that letter to the end and append'ay'. For example, 'happy' becomes 'appyhay' and 'pencil' becomes 'encilpay'.
# • If the word starts with a vowel, simply append 'way' to the end of the word.For example, 'enter' becomes 'enterway' and 'other' becomes 'otherway' . Forour purposes, there are 5 vowels: a, e, i, o, u (so we count y as a consonant).
# Write a function pig() that takes a word (i.e., a string) as input and returns its pig-Latin form. Your function should still work if the input word contains upper casecharacters. Your output should always be lower case however.
#
# pig('happy')
# 'appyhay'
#
# pig('Enter')
# 'enterway

# %%
def pig(word):
   
    word = word.lower()
    

    vowels = 'aeiou'
    if word[0] in vowels:
        return word + 'way'
    else:
        
        index = 0
        for i, char in enumerate(word):
            if char in vowels:
                index = i
                break
        
      
        return word[index:] + word[:index] + 'ay'


print(pig('happy'))  
print(pig('Enter'))
# Out:
# appyhay
# enterway

# %% [markdown]
# # Question 7
#
# File bloodtype1.txt records blood-types of patients (A, B, AB, O or OO) at a clinic.Write a function bldcount() that reads the file with name name and reports (i.e.,prints) how many patients there are in each bloodtype.
#
# bldcount('bloodtype.txt')
# There are 10 patients of blood type A.
# There is one patient of blood type B.
# There are 10 patients of blood type AB.
# There are 12 patients of blood type O.
# There are no patients of blood type OO.

# %%
def bldcount(filename):
   
    blood_type_count = {'A': 0, 'B': 0, 'AB': 0, 'O': 0, 'OO': 0}
    
    try:
        
        with open(filename, 'r') as file:
            blood_types = file.read().split()
            for blood_type in blood_types:
                if blood_type in blood_type_count:
                    blood_type_count[blood_type] += 1
    
      
        for blood_type, count in blood_type_count.items():
            if count == 1:
                print(f"There is one patient of blood type {blood_type}.")
            elif count > 1:
                print(f"There are {count} patients of blood type {blood_type}.")
            else:
                print(f"There are no patients of blood type {blood_type}.")
    
    except FileNotFoundError:
        print(f"File '{filename}' not found.")


bldcount('bloodtype.txt')

# %% [markdown]
# # Question 8
#
# Write a function curconv() that takes as input:
#      1. a currency represented using a string (e.g., 'JPY' for the Japanese Yen or'EUR' for the Euro)
#      2. an amount
# and then converts and returns the amount in US dollars.
# curconv('EUR', 100)
#
# 122.96544
#
# curconv('JPY', 100)1.241401
# The currency rates you will need are stored in file currencies.txt:
# AUD 1.0345157
# Australian Dollar
# CHF 1.0237414 Swiss Franc
# CNY 0.1550176 Chinese Yuan

# %%
def curconv(currency, amount):
    try:
        
    currency_rates = {}
    with open('currencies.txt', 'r') as file:
    lines = file.readlines()
    for line in lines:
    parts = line.split()
    if len(parts) >= 2:
    code, rate = parts[0], float(parts[1])
    currency_rates[code] = rate
        
       
    if currency in currency_rates:
    usd_amount = amount * currency_rates[currency]
    return usd_amount
  else:
    return "Currency code not found in the file."

  except FileNotFoundError:
    return "File 'currencies.txt' not found."


result1 = curconv('EUR', 100)
result2 = curconv('JPY', 100)

print(result1)
print(result2)

# %% [markdown]
# # Question 9
# Each of the following will cause an exception (an error). Identify what type ofexception each will cause.
# a. Trying to add incompatible variables, as inadding 6 + ‘a’
# b. Referring to the 12th item of a list that has only 10items
# c. Using a value that is out of range for a function’sinput, such as calling math.sqrt(-1.0)
# d. Using an undeclared variable, such as print(x)when x has not been defined
# e. Trying to open a file that does not exist, such asmistyping the file name or looking in the wrong directory

# %%
a. TypeError 
b. IndexError
c. ValueError
d. NameError
e. Missing file error

# %% [markdown]
# # Question 10
#
# Encryption is the process of hiding the meaning of a text by substituting letters in themessage with other letters, according to some system. If the process is successful, noone but the intended recipient can understand the encrypted message. Cryptanalysisrefers to attempts to undo the encryption, even if some details of the encryption areunknown (for example, if an encrypted message has been intercepted). The first stepof cryptanalysis is often to build up a table of letter frequencies in the encrypted text.Assume that the string letters is already defined as'abcdefghijklmnopqrstuvwxyz'. Write a function called frequencies()that takes a string as its only parameter, and returns a list of integers, showing thenumber of times each character appears in the text. Your function may ignore anycharacters that are not in letters.
#
# frequencies('The quick red fox got bored and went home.')[1, 1, 1, 3, 5, 1, 1, 2, 1, 0, 1, 0, 1, 2, 4, 0, 1, 2, 0, 2,1, 0, 1, 1, 0, 0]>>> frequencies('apple')

# %%
def frequencies(text):
   
   
letters = 'abcdefghijklmnopqrstuvwxyz'
     
letter_frequencies = [0] * 26
    
text = text.lower()
for char in text:
if char in letters:
           
index = letters.index(char)
letter_frequencies[index] += 1
return letter_frequencies

result1 = frequencies('The quick red fox got bored and went home.')
result2 = frequencies('apple')

print(result1)
print(result2)
